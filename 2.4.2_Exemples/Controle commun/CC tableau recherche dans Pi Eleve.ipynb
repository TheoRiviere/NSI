# %% [markdown]
# # tableaux recherche : dans Pi

# %% [markdown]
# Commencer par exécuter la cellule de code ci-dessous.

# %%
from mpmath import mp

def decimales_pi(n):
    mp.dps = n+1
    return str(mp.pi)[2:]

# %% [markdown]
# Cette fonction permet de renvoyer les `n` première décimales de pi ≈ 3,1415926535. Par exemple avec `n=10000` on obtient :
# Exécuter la cellule de code ci-dessous

# %%
PI = decimales_pi(10000)
PI

# %% [markdown]
# La chaîne de caractères `PI` contient désormais les 10 000 premières décimales de pi ≈ 3,1415926535 . Il faut rappeler qu'on lit les caractères d'une chaîne de caractères exactement comme on lit les valeurs d'un tableau ( grâce à leur indice) :

# %%
PI[0], PI[1], PI[2], PI[3], PI[4], PI[5], PI[6]

# %%
PI[9997], PI[9998], PI[9999]

# %% [markdown]
# **Dans toute la suite du notebook nous ne travaillerons qu'avec les 10000 premières décimales de pi et la chaîne de caractères `PI`.**

# %% [markdown]
# *Question 1 :*
#
# Compléter la fonction `decimales` ci-dessous qui prend en paramètre un indice `i` compris entre 0 et 9997 et renvoie la chaîne de caractères obtenue en concaténant les `i`, `i+1` et `i+2` ièmes décimales de pi.  Par exemple :
# - pour `i=0` la fonction doit renvoyer `'141'`,
# - pour `i=1` la fonction doit renvoyer `'415'`,
# - pour `i=2` la fonction doit renvoyer `'159'`,
# - pour `i=9996` la fonction doit renvoyer `'679'`.

# %%
def decimales(i, PI):
    chaine_3_chiffres = PI[...] + ... + ... 
    return ...

# %% [markdown]
# *Question 2 :*
#
# Tester votre fonction grâce au jeu de tests ci-dessous.

# %%
assert decimales(0,PI) == '141'
assert decimales(1,PI) == '415'
assert decimales(2,PI) == '159'
assert decimales(3,PI) == '592'
assert decimales(306,PI) == '006'
assert decimales(9997,PI) == '679'

# %% [markdown]
# *Question 3 :*
# Compléter votre fonction **decimales** par une assertion vérifiant la précondition de l'énoncé.

# %% [markdown]
# *Question 4 :*
#
# Compléter la fonction `chercher_dans_pi` ci-dessous qui prend en paramètre une chaîne de caractères `ch` de trois chiffres et :
# - si cette séquence de trois chiffres est présente dans les 10000 premières décimales de pi, renvoie le plus petit indice `i` auquel cette séquence est présente,
# - sinon renvoie -1.

# %%
def chercher_dans_pi(ch,PI): 
    assert len(ch) == 3 
    i = 0
    while i <= ... :
        if decimales(...,PI) == ... :
            return ...
        else:
            i = ... + ...
    return ...

# %% [markdown]
# Tester votre fonction avec le jeu de tests suivant.

# %%
assert chercher_dans_pi('777',PI) == 1588
assert chercher_dans_pi('000',PI) == 600
assert chercher_dans_pi('012',PI) == 658
assert chercher_dans_pi('123',PI) == 1923
assert chercher_dans_pi('789',PI) == 350
assert chercher_dans_pi('871',PI) == 2776
