# %% [markdown]
# # types des objets - drôles de sommes

# %% [markdown]
# Lorsqu'on effectue la somme $450 + 190$ on obtient $640$.
# Dans cette activité nous appellerons `drole_de_somme(450, 190)` le nombre entier `450190`.

# %% [markdown]
# **Nous allons ici implémenter deux fonctions permettant d'effectuer une «drôle de somme» sur des entiers compris entre 100 et 999. Mais ces deux fonctions utiliseront deux méthodes différentes :**
# - **une méthode calculatoire pour la première,**
# - **une méthode se basant sur un changement de type pour la seconde.**

# %% [markdown]
# ## Méthode 1 :

# %% [markdown]
# *Question 1 :* Compléter la fonction `drole_de_somme` qui prend en paramètres deux nombres entiers `a` et `b` compris entre `100` et `999` (c'est à dire comportant 3 chiffres chacun).
# On pourra par exemple remarquer - en reprenant l'exemple ci-dessus - que `450190 = 450000 + 190 = 450*100 + 190`.

# %%
def drole_de_somme(a, b):
    nombre = ... * ... + ...
    return nombre

# %% [markdown]
# *Question 2 :* On souhaite tester la fonction **drole_de_somme**.
# Ecrire ci-dessous 3 tests sous la forme d'assertion.

# %% [markdown]
# *Question 3 :* Compléter le code de votre fonction avec deux assertions correspondant aux préconditions portant sur `a` et `b` mentionnées dans l'énoncé de la question 1.

# %% [markdown]
# ## Méthode 2 :

# %% [markdown]
# *Question 1 :* Compléter la fonction `drole_de_somme_v2` qui prend en paramètres deux nombres entiers `a` et `b` compris entre `100` et `999` (c'est à dire comportant 3 chiffres chacun).
# On pourra par exemple remarquer - en reprenant l'exemple ci-dessus - que `"450190" = "450" + "190"` et profiter des conversions de type.

# %%
def drole_de_somme_v2(a, b):
    str_a = str(...)
    str_b = str(...)
    str_drole_de_somme = ... + ...
    return int(...)

# %% [markdown]
# *Question 2 :* Vérifier que votre fonction satisfait le jeu de tests suivant :

# %%
assert drole_de_somme_v2(130, 207) == 130207
assert drole_de_somme_v2(999, 654) == 999654
assert drole_de_somme_v2(154, 982) == 154982

# %% [markdown]
# *Question 3 :* Dans la fonction `drole_de_somme_v2`, l'opérateur `+` correspond à une opération qui a un nom bien précis en informatique. Quel est le nom précis de cette opération qui consiste à «coller» deux chaînes de caractères ensemble ?
# - caconténation,
# - concaténation,
# - caconatétion,
# - concanatétion.

# %% [markdown]
# **réponse ici**

# %% [markdown]
# ici
