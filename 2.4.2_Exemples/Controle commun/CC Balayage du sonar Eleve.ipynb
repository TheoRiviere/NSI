# %% [markdown]
# ![yo](https://capytale2.ac-paris.fr/web/sites/default/files/2021-12-06-18-53-45/ac-versailles-1/mln_charles.poulmaire/sous-marin.png)

# %% [markdown]
# Lorsque un sous-marin descend sous la surface de l'océan, il effectue automatiquement un balayage par sonar du fond marin à proximité. Il obtient des valeurs qui sont des mesures de la profondeur du fond marin.
# Ces valeurs sont enregistrées dans une liste [199, 200, 208, 210, 200, 207, 240, 269, 260, 263].
#
# Combien de valeurs sont supérieures à une valeur seuil ?
#
# Dans notre exemple, si le seuil est égal 210 à la réponse est 4.
#
#
# Combien de valeurs sont plus grandes que la valeurs précédente ?
#
# Dans notre exemple la réponse est 7.
#
# En effet :
#
# - 199, 200 augmentation
# - 200, 208 augmentation
# - 208, 210 augmentation
# - 210, 200 pas d'augmentation
# - 200, 207 augmentation
# - 207, 240 augmentation
# - 240, 269 augmentation
# - 269, 260 pas d'augmentation
# - 260, 263 augmentation

# %% [markdown]
# *Question 1 :*
#
# Ecrire une fonction **sup** qui a pour arguments une liste et une valeur seuil et qui renvoie le nombre de valeurs supérieures à la valeur seuil.

# %%
# Ecrire ici
def sup(liste,seuil):

# %%
Vous pouvez vérifier votre fonction en exécutant la cellule suivante

# %%
assert compte([199, 200, 208, 210, 200, 207, 240, 269, 260, 263],210) == 4

# %% [markdown]
# *Question 2 :*
#
# Compléter la fonction **compte** qui a pour argument une liste et qui renvoie le nombre de fois qu'une valeur augmente par rapport à la valeur précédente.

# %%
def compte(liste):
    nb = ...
    for i in range(...) :
        if liste[...] < liste[i+1]:
            nb = nb + ...
    return nb

# %% [markdown]
# Vous pouvez vérifier votre fonction en exécutant la cellule suivante

# %%
assert compte([199, 200, 208, 210, 200, 207, 240, 269, 260, 263]) == 7
